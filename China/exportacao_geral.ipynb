# %%
#importação de bibliotecas
import pandas as pd

# %%
#ler o arquivo csv
caminho_arquivo = ('./downloadData_todos_2024.csv')
dados = pd.read_csv(caminho_arquivo,delimiter=',')

# %%
#cria dataframe

data_frame = pd.DataFrame(dados)
print(data_frame.head)
# Out:
# <bound method NDFrame.head of     Date of data  Commodity code  \
# 0         202401            6401
# 1         202401            6402
# 2         202401            6403
# 3         202401            6404
# 4         202401            6405
# 5         202402            6401
# 6         202402            6402
# 7         202402            6403
# 8         202402            6404
# 9         202402            6405
# 10        202403            6401
# 11        202403            6402
# 12        202403            6403
# 13        202403            6404
# 14        202403            6405
# 15        202404            6401
# 16        202404            6402
# 17        202404            6403
# 18        202404            6404
# 19        202404            6405
# 20        202405            6401
# 21        202405            6402
# 22        202405            6403
# 23        202405            6404
# 24        202405            6405
# 25        202406            6401
# 26        202406            6402
# 27        202406            6403
# 28        202406            6404
# 29        202406            6405
# 30        202407            6401
# 31        202407            6402
# 32        202407            6403
# 33        202407            6404
# 34        202407            6405
# 35        202408            6401
# 36        202408            6402
# 37        202408            6403
# 38        202408            6404
# 39        202408            6405
# 40        202409            6401
# 41        202409            6402
# 42        202409            6403
# 43        202409            6404
# 44        202409            6405
# 45        202410            6401
# 46        202410            6402
# 47        202410            6403
# 48        202410            6404
# 49        202410            6405
# 50        202411            6401
# 51        202411            6402
# 52        202411            6403
# 53        202411            6404
# 54        202411            6405
# 55        202412            6401
# 56        202412            6402
# 57        202412            6403
# 58        202412            6404
# 59        202412            6405
#
#                                             Commodity      US dollar  \
# 0   Waterproof footwear with outer soles and upper...     53,172,148
# 1   Other footwear with outer soles and uppers of ...  3,035,022,792
# 2   ootwear with outer soles of rubber, plastics, ...    730,311,817
# 3   Footwear with outer soles of rubber, plastics,...  1,411,267,216
# 4                                     Other footwear.    109,892,157
# 5   Waterproof footwear with outer soles and upper...     33,049,578
# 6   Other footwear with outer soles and uppers of ...  1,814,707,876
# 7   ootwear with outer soles of rubber, plastics, ...    525,983,290
# 8   Footwear with outer soles of rubber, plastics,...    882,355,134
# 9                                     Other footwear.     58,467,579
# 10  Waterproof footwear with outer soles and upper...     39,216,572
# 11  Other footwear with outer soles and uppers of ...  1,576,607,397
# 12  ootwear with outer soles of rubber, plastics, ...    421,271,066
# 13  Footwear with outer soles of rubber, plastics,...    753,248,743
# 14                                    Other footwear.     95,453,733
# 15  Waterproof footwear with outer soles and upper...     49,142,136
# 16  Other footwear with outer soles and uppers of ...  1,978,257,508
# 17  ootwear with outer soles of rubber, plastics, ...    473,672,356
# 18  Footwear with outer soles of rubber, plastics,...    875,550,540
# 19                                    Other footwear.    115,434,645
# 20  Waterproof footwear with outer soles and upper...     63,098,569
# 21  Other footwear with outer soles and uppers of ...  2,240,052,796
# 22  ootwear with outer soles of rubber, plastics, ...    615,694,632
# 23  Footwear with outer soles of rubber, plastics,...  1,020,306,200
# 24                                    Other footwear.    113,145,434
# 25  Waterproof footwear with outer soles and upper...     71,530,228
# 26  Other footwear with outer soles and uppers of ...  2,213,761,985
# 27  ootwear with outer soles of rubber, plastics, ...    807,282,790
# 28  Footwear with outer soles of rubber, plastics,...  1,080,041,644
# 29                                    Other footwear.    124,459,220
# 30  Waterproof footwear with outer soles and upper...     66,580,038
# 31  Other footwear with outer soles and uppers of ...  2,128,151,063
# 32  ootwear with outer soles of rubber, plastics, ...    850,517,671
# 33  Footwear with outer soles of rubber, plastics,...  1,078,494,846
# 34                                    Other footwear.    145,416,115
# 35  Waterproof footwear with outer soles and upper...     60,914,616
# 36  Other footwear with outer soles and uppers of ...  1,959,423,815
# 37  ootwear with outer soles of rubber, plastics, ...    787,723,235
# 38  Footwear with outer soles of rubber, plastics,...  1,068,186,160
# 39                                    Other footwear.    139,188,941
# 40  Waterproof footwear with outer soles and upper...     50,908,281
# 41  Other footwear with outer soles and uppers of ...  1,621,691,625
# 42  ootwear with outer soles of rubber, plastics, ...    614,572,808
# 43  Footwear with outer soles of rubber, plastics,...    898,390,604
# 44                                    Other footwear.    133,720,826
# 45  Waterproof footwear with outer soles and upper...     49,345,240
# 46  Other footwear with outer soles and uppers of ...  1,702,008,756
# 47  ootwear with outer soles of rubber, plastics, ...    587,386,445
# 48  Footwear with outer soles of rubber, plastics,...    909,982,346
# 49                                    Other footwear.    121,365,703
# 50  Waterproof footwear with outer soles and upper...     49,806,567
# 51  Other footwear with outer soles and uppers of ...  1,919,789,756
# 52  ootwear with outer soles of rubber, plastics, ...    658,362,560
# 53  Footwear with outer soles of rubber, plastics,...  1,025,956,700
# 54                                    Other footwear.    126,960,739
# 55  Waterproof footwear with outer soles and upper...     61,081,968
# 56  Other footwear with outer soles and uppers of ...  2,493,783,269
# 57  ootwear with outer soles of rubber, plastics, ...    764,675,317
# 58  Footwear with outer soles of rubber, plastics,...  1,245,555,416
# 59                                    Other footwear.    166,111,980
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN
# 56         NaN
# 57         NaN
# 58         NaN
# 59         NaN  >

# %%
#remove virgulas dos numeros
data_frame['US dollar'] = data_frame['US dollar'].astype(str).str.replace(',','', regex= False)
#converte de volta para número
data_frame['US dollar'] = pd.to_numeric(data_frame['US dollar'], errors = 'coerce')

# %%
#cria coluna de ano
data_frame['ano']= data_frame['Date of data'].astype(str).str[:4]

# %%
#cria coluna mês
data_frame['mes'] = data_frame['Date of data'].astype(str).str[4:6].str.zfill(2)

# %%
#cria coluna dia
data_frame['dia'] = '01'

# %%
#cria coluna data
data_frame['data'] = data_frame['dia'] + "/" + data_frame['mes'] + "/" + data_frame['ano']

# %%
#ordena as colunas
data_frame = data_frame[['ano', 'mes', 'dia', 'data', 'Commodity code','US dollar']]

# %%
#cria quantidade estatística
data_frame['Quantidade Estatística'] = 0

# %%
#converte colunas
data_frame = data_frame.astype({
    'ano': int,
    'mes': int,
    'dia': int
})

# %%
#ordena os dados
data_frame = data_frame.sort_values(by=['mes','Commodity code'], ascending=True)

# %%
#exporta para excel
data_frame.to_excel('./china_total.xlsx', index=False, header = True)
